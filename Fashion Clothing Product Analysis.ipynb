# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 10px;">Fashion Clothing Product Analysis🛍️</h1>
#     <p style="text-align: center; font-size: 18px; color: white;">This Notebook give insights based on the Myntra Fashion Clothing Data using Exploratory Data Analysis, and helps in understanding the trends using various features.</p>
# </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## **ABOUT THE AUTHOR**

# %% [markdown]
# Hi there! I'm Akshay Shekade, a data scientist in training. I'm diving into the world of data science and exploring various concepts and techniques to enhance my skills. Join me on this exciting journey as we learn and grow in the field of data science together.
#
# > "Community is the heart of growth and learning. Together, we can achieve more than we ever could alone."
#
# | Name               | Email                                               | LinkedIn                                                  | GitHub                                           | Kaggle                                      |
# |--------------------|-----------------------------------------------------|-----------------------------------------------------------|--------------------------------------------------|-----------------------------------------------|
# | **Akshay Shekade**      |akshayshekade757@gmail.com  | [![LinkedIn Badge](https://img.shields.io/badge/LinkedIn-%23000000.svg?style=for-the-badge&logo=LinkedIn&logoColor=white)](https://www.linkedin.com/in/akshay-shekade-a225a8135/)  | [![GitHub Badge](https://img.shields.io/badge/GitHub-%23000000.svg?style=for-the-badge&logo=GitHub&logoColor=white)](https://github.com/AkshayShekade)  | [![Kaggle Badge](https://img.shields.io/badge/Kaggle-%23000000.svg?style=for-the-badge&logo=Kaggle&logoColor=white)](https://www.kaggle.com/akshayshekade)  |

# %% [markdown]
# > LETS BEGIN :)

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Importing all the Necessary Packages 💻📊</h1>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Reading the First dataset💻📊</h1>
# </div>

# %%
df1 = pd.read_csv(r"C:\Users\ACER\Desktop\product details.csv")

# %%
df1.head()
# Out:
#    ProductID                                        ProductName ProductBrand
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx

# %% [markdown]
# **Information About First Dataset**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     12491 non-null  int64
#  1   ProductName   12491 non-null  object
#  2   ProductBrand  12491 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 292.9+ KB

# %% [markdown]
# **Basic Statistics Of The First Dataset**

# %%
df1.describe(include = "all")
# Out:
#            ProductID                                  ProductName  \
# count   1.249100e+04                                        12491
# unique           NaN                                        10761
# top              NaN  Parx Men Blue Slim Fit Checked Casual Shirt
# freq             NaN                                           16
# mean    9.917160e+06                                          NaN
# std     1.438006e+06                                          NaN
# min     1.012060e+05                                          NaN
# 25%     1.006215e+07                                          NaN
# 50%     1.015463e+07                                          NaN
# 75%     1.021565e+07                                          NaN
# max     1.027514e+07                                          NaN
#
#           ProductBrand
# count            12491
# unique             677
# top     Indian Terrain
# freq               971
# mean               NaN
# std                NaN
# ...

# %% [markdown]
# **Checking For Missing Values**

# %%
df1.isnull().sum()
# Out:
# ProductID       0
# ProductName     0
# ProductBrand    0
# dtype: int64

# %% [markdown]
# **Checking For Duplicated Values**

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Reading the Second dataset💻📊</h1>
# </div>

# %%
df2 = pd.read_csv(r"C:\Users\ACER\Desktop\products catalog.csv")

# %%
df2.head()
# Out:
#   Gender  Price (INR)  NumImages        ID  \
# 0  Women          593          5  10182131
# 1    Men         6396          5  10052169
# 2  Women          599          5  10168643
# 3    Men         1034          5  10155427
# 4    Men          477          3  10191059
#
#                                          Description PrimaryColor
# 0  Off-White printed woven A-line  top, has a rou...        White
# 1  Display: AnalogueMovement: QuartzPower source:...        Black
# 2  Blue printed knitted regular  top, has a high ...         Blue
# 3  Grey and Purple checked smart casual shirt, ha...         Grey
# 4  Beige and Brown striped beltReversible: NoStre...        Brown

# %% [markdown]
# **Information About Second Dataset**

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Gender        12491 non-null  object
#  1   Price (INR)   12491 non-null  int64
#  2   NumImages     12491 non-null  int64
#  3   ID            12491 non-null  int64
#  4   Description   12491 non-null  object
#  5   PrimaryColor  11597 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 585.6+ KB

# %% [markdown]
# **Basic statistics Of The Second Dataset**

# %%
df2.describe(include = "all")
# Out:
#        Gender   Price (INR)     NumImages            ID  \
# count   12491  12491.000000  12491.000000  1.249100e+04
# unique      6           NaN           NaN           NaN
# top     Women           NaN           NaN           NaN
# freq     5126           NaN           NaN           NaN
# mean      NaN   1452.660956      4.913698  9.917160e+06
# std       NaN   2118.503976      1.092333  1.438006e+06
# min       NaN     90.000000      1.000000  1.012060e+05
# 25%       NaN    649.000000      5.000000  1.006215e+07
# 50%       NaN    920.000000      5.000000  1.015463e+07
# 75%       NaN   1499.000000      5.000000  1.021565e+07
# max       NaN  63090.000000     10.000000  1.027514e+07
#
#                                               Description PrimaryColor
# count                                               12491        11597
# unique                                              10435           27
# top     Blue medium wash 5-pocket mid-rise jeans, clea...         Blue
# ...

# %% [markdown]
# **Cheching For The Missing Values**

# %%
df2.isnull( ).sum()
# Out:
# Gender            0
# Price (INR)       0
# NumImages         0
# ID                0
# Description       0
# PrimaryColor    894
# dtype: int64

# %% [markdown]
# **Checking For Duplicated Values**

# %%
df2.duplicated( ).sum()
# Out:
# 0

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Merge Both The datasets💻📊</h1>
# </div>

# %%
data = pd.merge(df1, df2, how = "inner", left_on = "ProductID", right_on = 'ID')

# %%
data.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages        ID  \
# 0  Unisex        11745          7  10017413
# 1   Women         5810          7  10016283
# 2   Women          899          7  10009781
# 3     Men         5599          5  10015921
# 4     Men          759          5  10017833
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# ...

# %% [markdown]
# **Information About New Dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     12491 non-null  int64
#  1   ProductName   12491 non-null  object
#  2   ProductBrand  12491 non-null  object
#  3   Gender        12491 non-null  object
#  4   Price (INR)   12491 non-null  int64
#  5   NumImages     12491 non-null  int64
#  6   ID            12491 non-null  int64
#  7   Description   12491 non-null  object
#  8   PrimaryColor  11597 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 878.4+ KB

# %% [markdown]
# **Basic Statistics For The New Dataset**

# %%
data.describe(include = "all")
# Out:
#            ProductID                                  ProductName  \
# count   1.249100e+04                                        12491
# unique           NaN                                        10761
# top              NaN  Parx Men Blue Slim Fit Checked Casual Shirt
# freq             NaN                                           16
# mean    9.917160e+06                                          NaN
# std     1.438006e+06                                          NaN
# min     1.012060e+05                                          NaN
# 25%     1.006215e+07                                          NaN
# 50%     1.015463e+07                                          NaN
# 75%     1.021565e+07                                          NaN
# max     1.027514e+07                                          NaN
#
#           ProductBrand Gender   Price (INR)     NumImages            ID  \
# count            12491  12491  12491.000000  12491.000000  1.249100e+04
# ...

# %% [markdown]
# **Remove The Duplicate Column**

# %%
data.drop(['ID'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %% [markdown]
# **Checking For the Missing Values**

# %%
data.isnull().sum()
# Out:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    894
# dtype: int64

# %% [markdown]
# **Filling Missing Values**

# %%
data['PrimaryColor'].fillna('Others', inplace=True)

# %%
data.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %%
data.isnull().sum()
# Out:
# ProductID       0
# ProductName     0
# ProductBrand    0
# Gender          0
# Price (INR)     0
# NumImages       0
# Description     0
# PrimaryColor    0
# dtype: int64

# %% [markdown]
# **Checking For The Duplicated Values**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Dropping The Duplicated Values**

# %%
data.drop_duplicates(inplace = True)

# %%
data.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %% [markdown]
# **Separate The Names Of The Categorical And Numerical Columns**

# %%
cat_cols = data.select_dtypes(include=['object']).columns.tolist()
print(cat_cols)

num_cols = data.select_dtypes(exclude=['object']).columns.tolist()
print(num_cols)
# Out:
# ['ProductName', 'ProductBrand', 'Gender', 'Description', 'PrimaryColor']
# ['ProductID', 'Price (INR)', 'NumImages']

# %% [markdown]
# **Check For The Unique Values in Categorical Column**

# %%
for i in cat_cols : 
    print("Column name :",i)
    print(data[i].unique())
    print()
# Out:
# Column name : ProductName
# ['DKNY Unisex Black & Grey Printed Medium Trolley Bag'
#  'EthnoVogue Women Beige & Grey Made to Measure Custom Made Kurta Set with Jacket'
#  'SPYKAR Women Pink Alexa Super Skinny Fit High-Rise Clean Look Stretchable Cropped Jeans'
#  ... '612 league Girls Navy Blue & White Printed Regular Fit Denim Shorts'
#  'Bvlgari Men Aqva Pour Homme Marine Eau de Toilette 150ml'
#  'Pepe Jeans Men Black & Grey Striped Polo Collar T-shirt']
#
# Column name : ProductBrand
# ['DKNY' 'EthnoVogue' 'SPYKAR' 'Raymond' 'Parx' 'SHOWOFF' 'Kenneth Cole'
#  'Police' 'Vishudh' 'Being Human' 'Homesake' 'SEJ by Nisha Gupta'
#  'YAK YAK' 'PARFAIT' 'Michael Kors' 'HIGHLANDER' 'JEWEL JUNCTION' 'ID'
#  'Story@home' 'Gini and Jony' 'Sera' 'AccessHer' 'Alcis'
#  'Difference of Opinion' 'Tokyo Talkies' 'ANNA SUI' 'her by invictus'
#  'Soie' 'Lara Karen' 'Urban Dog' 'ahilya' 'VASTRAMAY' 'Campus Sutra'
#  'FIDO DIDO' 'MIAH Decor' 'BuckleUp' 'Peter England' 'AIGNER' 'Lady Lyka'
# ...

# %% [markdown]
# **Check For The Number Of Unique Values in Categorical Column**

# %%
for i in cat_cols : 
    print(f"Column Name = '{i}'")
    print(f"Total Unique Values = {data[i].nunique()}")
    print("__" * 30)
# Out:
# Column Name = 'ProductName'
# Total Unique Values = 10761
# ____________________________________________________________
# Column Name = 'ProductBrand'
# Total Unique Values = 677
# ____________________________________________________________
# Column Name = 'Gender'
# Total Unique Values = 6
# ____________________________________________________________
# Column Name = 'Description'
# Total Unique Values = 10435
# ____________________________________________________________
# Column Name = 'PrimaryColor'
# Total Unique Values = 28
# ____________________________________________________________

# %% [markdown]
# **Removing Spaces From Primary Column**

# %%
data['PrimaryColor'] = data['PrimaryColor'].str.lstrip()

# %%
data['PrimaryColor'].unique()
# Out:
# array(['Black', 'Beige', 'Pink', 'Blue', 'White', 'Brown', 'Burgundy',
#        'Red', 'Green', 'Others', 'Maroon', 'Navy', 'Gold', 'Yellow',
#        'Grey', 'Platinum', 'Silver', 'Khaki', 'Mustard', 'Lavender',
#        'Matte', 'Rose', 'Charcoal', 'Purple', 'Orange', 'Peach',
#        'Magenta', 'Bronze'], dtype=object)

# %% [markdown]
# **Rename Price (INR) column to Price**

# %%
data.rename( columns = {"Price (INR)" : "Price"}, inplace = True )

# %%
data.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Data Visualization💻📊</h1>
# </div>

# %% [markdown]
# **Gender Distribution**

# %%
gender_group = data.groupby("Gender").aggregate(TotalRecords = ("ProductID", "size"))
gender_group = gender_group.sort_values(by = "TotalRecords", ascending = False)

gender_group.head()
# Out:
#         TotalRecords
# Gender
# Women           5126
# Men             4591
# Unisex          1188
# Boys            1100
# Girls            440

# %% [markdown]
# **The Bar Plot Shows The Gender Distribution**

# %%
plt.figure(  figsize = (10, 5) )
sns.barplot(x = gender_group.index.values, y = gender_group.TotalRecords.values, palette = "Paired")
plt.xlabel("Gender")
plt.ylabel("Total Records")
plt.title("Gender Vs Total Records")
plt.show()

# %% [markdown]
# **Number Of Image Distribution**

# %%
images_group = data.groupby("NumImages").aggregate(  TotalRecords = ("ProductID", "size"))
images_group = images_group.sort_values(by = "NumImages")

images_group
# Out:
#            TotalRecords
# NumImages
# 1                    13
# 2                   174
# 3                  1211
# 4                  1693
# 5                  7134
# 6                  1080
# 7                  1057
# 8                   102
# 9                    24
# 10                    3

# %% [markdown]
# **The Bar Plot Shows The Image Distribution**

# %%
plt.figure(  figsize = (10, 5) )
sns.barplot(x = images_group.index.values, y = images_group.TotalRecords.values, palette = "viridis")
plt.xlabel("Num Of Images")
plt.ylabel("Total Records")
plt.title("Num Of Images Vs Total Records")
plt.show()

# %% [markdown]
# ### Analyzing "ProductBrand" Group:
# #### Studying their total records, average price and average images for top 15 values against each of the category

# %%
products_group = data.groupby("ProductBrand").aggregate( TotalRecords = ("ProductID", 'size'), 
                                                        AvgPrice = ("Price", 'mean'), 
                                                        MaxPrice = ("Price", "max"))
products_group.head()
# Out:
#               TotalRecords   AvgPrice  MaxPrice
# ProductBrand
# 109F                     1  1299.0000      1299
# 20Dresses                3  1153.0000      1396
# 612 league              16   713.3125      1395
# 7Rainbow                 3   598.0000       620
# AASK                     1  1499.0000      1499

# %% [markdown]
# **The Subplots Shows The Analysis Of Product Group**

# %%
plt.figure(  figsize = (15, 6) )
plt.suptitle("ANALYSIS OF PRODUCT GROUP", fontsize = 20)


plt.subplot(1, 3, 1)
sns.barplot(x = products_group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = products_group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "viridis")
plt.xticks(rotation = 90)
plt.title( f" Number of Records :  {products_group.index.name}")

plt.subplot(1, 3, 2)
sns.barplot(x = products_group.sort_values(by = 'AvgPrice', ascending = False).index[ : 15], 
            y = products_group.sort_values(by = 'AvgPrice', ascending = False).AvgPrice.values[ : 15], 
            palette = "viridis")
plt.xticks(rotation = 90)
plt.title( f" Avg Price by :  {products_group.index.name}")

plt.subplot(1, 3, 3)
sns.barplot(x = products_group.sort_values(by = 'MaxPrice', ascending = False).index[ : 15], 
            y = products_group.sort_values(by = 'MaxPrice', ascending = False).MaxPrice.values[ : 15], 
            palette = "viridis")
plt.xticks(rotation = 90)
plt.title( f" MaxPrice by :  {products_group.index.name}")

plt.show()

# %% [markdown]
# ### Analyzing "PrimaryColour" Group:
# #### Studying their total records, average price and average images for top 15 values against each of the category

# %%
colors_group = data.groupby("PrimaryColor").aggregate( TotalRecords = ("ProductID", 'size'), 
                                                   AvgPrice = ("Price", 'mean'))
colors_group.head()
# Out:
#               TotalRecords     AvgPrice
# PrimaryColor
# Beige                  236  1402.004237
# Black                 1640  1951.487805
# Blue                  3443  1350.478652
# Bronze                   3   588.000000
# Brown                  473  1540.021142

# %% [markdown]
# **The Subplots Shows The Analysis Of Primary Colour Group**

# %%
plt.figure(  figsize = (15, 6) )
plt.suptitle("Analysis of Primary Color Group", fontsize = 20)


plt.subplot(1, 2, 1)
sns.barplot(x = colors_group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = colors_group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "BrBG")
plt.xticks(rotation = 90)
plt.title( f" Number of Records")

plt.subplot(1, 2, 2)
sns.barplot(x = colors_group.sort_values(by = 'AvgPrice', ascending = False).index[ : 15], 
            y = colors_group.sort_values(by = 'AvgPrice', ascending = False).AvgPrice.values[ : 15], 
            palette = "BrBG")
plt.xticks(rotation = 90)
plt.title( f" Avg Price ")

plt.show()

# %% [markdown]
# **The Histogram Shows The Price  Distribution Of The Products**

# %%
plt.figure(  figsize = (10, 5) )

sns.histplot( x = data['Price'] , color = "c", bins = 25)

plt.xlabel("Price")
plt.ylabel(" Frequency ")
plt.title("Price Distribution")
plt.show()

# %% [markdown]
# **Description Of The Price Present In The Dataset**

# %%
data['Price'].describe()
# Out:
# count    12491.000000
# mean      1452.660956
# std       2118.503976
# min         90.000000
# 25%        649.000000
# 50%        920.000000
# 75%       1499.000000
# max      63090.000000
# Name: Price, dtype: float64

# %% [markdown]
# #### The price range in our dataset spans from Rs. 90/- to Rs. 63,000/-, with an average price of around Rs. 1,400/-.
# #### This variation is visually apparent from the chart.
#
# #### To delve deeper into the analysis, we are narrowing our focus to prices less than Rs. 10,000/-.
# #### This allows us to gain more insights into the distribution of prices within a more specific range, enabling us to discern patterns and trends that might not be as evident when considering the entire price range.

# %% [markdown]
# **The Histogram Shows The Distribution Of The Price less than Rs. 10,000/-.**

# %%
new_data = data[ data['Price'] <= 10000  ]

plt.figure(  figsize = (15, 6) )

sns.histplot( x = new_data['Price'] , color='m', bins = 50)

plt.xlabel("Price")
plt.ylabel(" Frequency ")
plt.title("Price Distribution")
plt.show()

# %% [markdown]
# **Description Of The Price Which Is less than Rs. 10,000/-**

# %%
new_data['Price'].describe()
# Out:
# count    12397.000000
# mean      1325.894733
# std       1224.723968
# min         90.000000
# 25%        649.000000
# 50%        919.000000
# 75%       1484.000000
# max       9999.000000
# Name: Price, dtype: float64

# %% [markdown]
# #### The most of customers tend to purchase items within the price range of Rs. 0 to Rs. 2,000/-.

# %% [markdown]
# **The Histogram Shows The Price Distribution**

# %%
df = data[ data['Price'] > 10000  ]

plt.figure(  figsize = (13, 5) )

sns.histplot( x = df['Price'] , color = 'g', bins = 50)

plt.xlabel("Price")
plt.ylabel(" Frequency ")
plt.title("Price Distribution")
plt.show()

# %%
df['Price'].describe()
# Out:
# count       94.000000
# mean     18170.968085
# std      10870.750193
# min      10125.000000
# 25%      11700.000000
# 50%      14200.500000
# 75%      20398.000000
# max      63090.000000
# Name: Price, dtype: float64

# %% [markdown]
# #### There's a substantial portion of customers who make purchases at Rs. 10,000 and beyond, indicating a notable interest in higher-priced products as well.

# %% [markdown]
# **The Histogram Shows Price Distribution**

# %%
plt.figure(  figsize = (10, 5) )

sns.histplot( x = data['Price'] , hue = data['Gender'], palette = "PuRd", bins = 25, multiple="stack")

plt.xlabel("Price")
plt.ylabel(" Frequency ")
plt.title("Price Distribution")
plt.show()

# %% [markdown]
# **The Histogram Shows Price Distribution Of Price Less Than Equal To Rs. 10,000/-**

# %%
df = data[ data['Price'] <= 10000  ]

plt.figure(  figsize = (10, 5) )

sns.histplot( x = df['Price'] ,hue = df['Gender'], palette = "PuRd", bins = 20, multiple="stack")

plt.xlabel("Price")
plt.ylabel(" Frequency ")
plt.title("Price Distribution")
plt.show()

# %% [markdown]
# **The Histogram Shows Price Distribution Of Price Greater Than Rs. 10,000/-**

# %%
df3 = data[ data['Price'] > 10000  ]

plt.figure(  figsize = (10, 5) )

sns.histplot( x = df3['Price'] ,hue = df3['Gender'], palette = "PuRd", bins = 20, multiple="stack")

plt.xlabel("Price")
plt.ylabel(" Frequency ")
plt.title("Price Distribution")
plt.show()

# %% [markdown]
# - #### For purchases under Rs. 10,000/-, the product appeals to all gender groups.
# - #### Once the price exceeds Rs. 10,000/-, it becomes a hit among everyone: unisex, women, and men alike.
# - #### Hovering around the Rs. 1,000/- mark, it's a must-have for the majority of women shoppers.

# %% [markdown]
# **Creating A New Column To "NewGender" Analyze Further Distribution**

# %%
data['NewGender'] = data['Gender'].copy()

# %%
data.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor NewGender
# 0  Black and grey printed medium trolley bag, sec...        Black    Unisex
# 1  Beige & Grey made to measure kurta with churid...        Beige     Women
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink     Women
# ...

# %% [markdown]
# **Replacing The Objects**

# %%
data['NewGender'].replace({"Unisex Kids" : "Unisex", 
                        "Boys" : "Men", 
                        "Girls" : "Women"}, inplace = True)

# %%
data['NewGender'].unique()
# Out:
# array(['Unisex', 'Women', 'Men'], dtype=object)

# %% [markdown]
# ### Analyzing  "Gender" Groups:
# #### Studying their total records, average price and average images  against each of the category.

# %%
newgender_group = data.groupby("NewGender").aggregate( TotalRecords = ("ProductID", 'size'), 
                                                   AvgPrice = ("Price", 'mean'))
newgender_group
# Out:
#            TotalRecords     AvgPrice
# NewGender
# Men                5691  1434.021613
# Unisex             1234  2120.924635
# Women              5566  1323.562702

# %% [markdown]
# **The Barplot Shows Analysis Of NewGender Group Based On Total Records And Average Amount Spent**

# %%
plt.figure(  figsize = (15, 6) )
plt.suptitle("Analysis of NewGender Group", fontsize = 20)


plt.subplot(1, 2, 1)
sns.barplot(x = newgender_group.sort_values(by = 'TotalRecords', ascending = False).index, 
            y = newgender_group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values, 
            palette = "Set3")
plt.title( f" Number of Records :  {newgender_group.index.name}")

plt.subplot(1, 2, 2)
sns.barplot(x = newgender_group.sort_values(by = 'AvgPrice', ascending = False).index, 
            y = newgender_group.sort_values(by = 'AvgPrice', ascending = False).AvgPrice.values, 
            palette = "Set3")
plt.title( f" Avg Amount spent by :  {newgender_group.index.name}")


plt.show()

# %% [markdown]
# ### Analyzing  "Gender" To "ProductBrand":
# #### Studying their total records, average price and average images for top 15 product brand values against each of the category.

# %%
data_gender = data[ data['NewGender'] == "Women" ]

women_group = data_gender.groupby("ProductBrand").aggregate( TotalRecords = ("ProductID", 'size'),
                                    AvgPrice = ("Price", 'mean'), AvgImages = ("NumImages", "mean"))
women_group.head()
# Out:
#               TotalRecords  AvgPrice  AvgImages
# ProductBrand
# 109F                     1    1299.0        5.0
# 20Dresses                3    1153.0        5.0
# 612 league               5     662.4        3.4
# 7Rainbow                 3     598.0        5.0
# AASK                     1    1499.0        5.0

# %% [markdown]
# **The Barplot Shows Analysis Of Women Group Based On Total Records, Average Amount Spent And Average Images**

# %%
plt.figure(  figsize = (15, 5) )
plt.suptitle("Analysis of Women Group", fontsize = 20)


plt.subplot(1, 3, 1)
sns.barplot(x = women_group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = women_group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "Spectral")
plt.xticks(rotation = 90)
plt.title( f" Number of Records :  {women_group.index.name}")

plt.subplot(1, 3, 2)
sns.barplot(x = women_group.sort_values(by = 'AvgPrice', ascending = False).index[ : 15], 
            y = women_group.sort_values(by = 'AvgPrice', ascending = False).AvgPrice.values[ : 15], 
            palette = "Spectral")
plt.xticks(rotation = 90)
plt.title( f" Avg Amount spent by :  {women_group.index.name}")

plt.subplot(1, 3, 3)
sns.barplot(x = women_group.sort_values(by = 'AvgImages', ascending = False).index[ : 15], 
            y = women_group.sort_values(by = 'AvgImages', ascending = False).AvgImages.values[ : 15], 
            palette = "Spectral")
plt.xticks(rotation = 90)
plt.title( f" Average Images by :  {women_group.index.name}")

plt.show()

# %%
data_gender = data[ data['NewGender'] == "Men" ]

men_group = data_gender.groupby("ProductBrand").agg( TotalRecords = ("ProductID", 'size'), 
                                                   AvgPrice = ("Price", 'mean'), AvgImages = ("NumImages", "mean"))
men_group.head()
# Out:
#                   TotalRecords     AvgPrice  AvgImages
# ProductBrand
# 612 league                  11   736.454545   3.636364
# ADIDAS                       4  3736.500000   5.000000
# ADIDAS Originals             1  7199.000000   7.000000
# AIGNER                       4  2860.000000   4.750000
# Aj DEZInES                   7   730.714286   4.714286

# %% [markdown]
# **The Barplot Shows Analysis Of Men Group Based On Total Records, Average Amount Spent And Average Images**

# %%
plt.figure(  figsize = (15, 6) )
plt.suptitle("Analysis of Men Group", fontsize = 20)


plt.subplot(1, 3, 1)
sns.barplot(x = men_group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = men_group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "RdYlBu")
plt.xticks(rotation = 90)
plt.title( f" Number of Records :  {men_group.index.name}")

plt.subplot(1, 3, 2)
sns.barplot(x = men_group.sort_values(by = 'AvgPrice', ascending = False).index[ : 15], 
            y = men_group.sort_values(by = 'AvgPrice', ascending = False).AvgPrice.values[ : 15], 
            palette = "RdYlBu")
plt.xticks(rotation = 90)
plt.title( f" Avg Amount spent by :  {men_group.index.name}")

plt.subplot(1, 3, 3)
sns.barplot(x = men_group.sort_values(by = 'AvgImages', ascending = False).index[ : 15], 
            y = men_group.sort_values(by = 'AvgImages', ascending = False).AvgImages.values[ : 15], 
            palette = "RdYlBu")
plt.xticks(rotation = 90)
plt.title( f" Average Images by :  {men_group.index.name}")

plt.show()

# %%
data_gender = data[ data['NewGender'] == "Unisex" ]

unisex_group = data_gender.groupby("ProductBrand").agg( TotalRecords = ("ProductID", 'size'), 
                                                   AvgPrice = ("Price", 'mean'), 
                                                   AvgImages = ("NumImages", "mean"))
unisex_group.head()
# Out:
#                  TotalRecords    AvgPrice  AvgImages
# ProductBrand
# Aapno Rajasthan             3  570.666667   4.000000
# AccessHer                   1  380.000000   4.000000
# Aditi Wasan                 2  502.000000   5.000000
# Alina decor                19  631.421053   4.842105
# Archies                    75  763.000000   3.306667

# %% [markdown]
# **The Barplot Shows Analysis Of Unisex Group Based On Total Records, Average Amount Spent And Average Images**

# %%
plt.figure(  figsize = (15, 6) )
plt.suptitle("Analysis of Unisex Group", fontsize = 20)


plt.subplot(1, 3, 1)
sns.barplot(x = unisex_group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = unisex_group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "YlOrRd")
plt.xticks(rotation = 90)
plt.title( f" Number of Records :  {unisex_group.index.name}")

plt.subplot(1, 3, 2)
sns.barplot(x = unisex_group.sort_values(by = 'AvgPrice', ascending = False).index[ : 15], 
            y = unisex_group.sort_values(by = 'AvgPrice', ascending = False).AvgPrice.values[ : 15], 
            palette = "YlOrRd")
plt.xticks(rotation = 90)
plt.title( f" Avg Amount spent by :  {unisex_group.index.name}")

plt.subplot(1, 3, 3)
sns.barplot(x = unisex_group.sort_values(by = 'AvgImages', ascending = False).index[ : 15], 
            y = unisex_group.sort_values(by = 'AvgImages', ascending = False).AvgImages.values[ : 15], 
            palette = "YlOrRd")
plt.xticks(rotation = 90)
plt.title( f" Average Images by :  {unisex_group.index.name}")

plt.show()

# %% [markdown]
# ### Analyzing  "Gender" To "PrimaryColor":
# #### Studying their total records for top 15 values against each of the category.

# %% [markdown]
# **The Barplots Shows The Colour Choices For Each Group**

# %%
plt.figure(  figsize = (15, 6) )
plt.suptitle("Apparel Color decision by Gender", fontsize = 20)

plt.subplot(1, 3, 1)
data_gender = data[ data['NewGender'] == "Women" ]
group = data_gender.groupby("PrimaryColor").agg( TotalRecords = ("ProductID", 'size'))
sns.barplot(x = group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "PuRd")
plt.xticks(rotation = 90)
plt.title( f" Color Choice by {data_gender['NewGender'].unique()[0]}")

plt.subplot(1, 3, 2)
data_gender = data[ data['NewGender'] == "Men" ]
group = data_gender.groupby("PrimaryColor").agg( TotalRecords = ("ProductID", 'size'))
sns.barplot(x = group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "PuRd")
plt.xticks(rotation = 90)
plt.title( f" Color Choice by {data_gender['NewGender'].unique()[0]}")

plt.subplot(1, 3, 3)
data_gender = data[ data['NewGender'] == "Unisex" ]
group = data_gender.groupby("PrimaryColor").agg( TotalRecords = ("ProductID", 'size'))
sns.barplot(x = group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "PuRd")
plt.xticks(rotation = 90)
plt.title( f" Color Choice by {data_gender['NewGender'].unique()[0]}")


plt.show()

# %% [markdown]
# ### Create Description Length Columns:

# %%
data['Length'] = data.Description.apply(lambda x : len(x))

# %%
data.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor NewGender  \
# 0  Black and grey printed medium trolley bag, sec...        Black    Unisex
# 1  Beige & Grey made to measure kurta with churid...        Beige     Women
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink     Women
# ...

# %% [markdown]
# ### Analyzing  "Gender" Groups with "Description Length":
# #### Studying their total records, average length against each of the category.

# %%
newgender_group = data.groupby("NewGender").agg( TotalRecords = ("ProductID", 'size'), 
                                                   AvgLength = ("Length", 'mean'))
newgender_group
# Out:
#            TotalRecords   AvgLength
# NewGender
# Men                5691  140.587243
# Unisex             1234  198.464344
# Women              5566  169.492454

# %% [markdown]
# **The Barplot Shows Analysis Of Women Group Based On Total Records And Average Description Length Spent**

# %%
plt.figure(  figsize = (15, 6) )
plt.suptitle("Analysis of Gender Group", fontsize = 20)


plt.subplot(1, 2, 1)
sns.barplot(x = newgender_group.sort_values(by = 'TotalRecords', ascending = False).index, 
            y = newgender_group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values, 
            palette = "tab20c")
plt.title( f" Number of Records :  {newgender_group.index.name}")

plt.subplot(1, 2, 2)
sns.barplot(x = newgender_group.sort_values(by = 'AvgLength', ascending = False).index, 
            y = newgender_group.sort_values(by = 'AvgLength', ascending = False).AvgLength.values, 
            palette = "tab20c")
plt.title( f" Avg Description Length spent by :  {newgender_group.index.name}")


plt.show()

# %% [markdown]
# ### Analyzing  "ProductBrand" Groups with "Description Length":
# #### Studying their total records, average length for top 15 values against each of the category.

# %%
products_group = data.groupby("ProductBrand").agg( TotalRecords = ("ProductID", 'size'), 
                                                  AvgPrice = ("Price", 'mean'),
                                                  AvgImages = ("NumImages", "mean"),
                                                  AvgLength = ("Length", 'mean'))
products_group.head()
# Out:
#               TotalRecords   AvgPrice  AvgImages  AvgLength
# ProductBrand
# 109F                     1  1299.0000     5.0000   102.0000
# 20Dresses                3  1153.0000     5.0000   110.0000
# 612 league              16   713.3125     3.5625   112.3125
# 7Rainbow                 3   598.0000     5.0000   365.0000
# AASK                     1  1499.0000     5.0000    69.0000

# %% [markdown]
# **The Bar Plot Shows The Analysis Of Product Group Based On TotalRecords, AvgPrice, AvgImages And AvgLength**

# %%
plt.figure(  figsize = (15, 6) )
plt.suptitle("Analysis of Products Group", fontsize = 20)


plt.subplot(1, 4, 1)
sns.barplot(x = products_group.sort_values(by = 'TotalRecords', ascending = False).index[ : 15], 
            y = products_group.sort_values(by = 'TotalRecords', ascending = False).TotalRecords.values[ : 15], 
            palette = "tab20b")
plt.xticks(rotation = 90)
plt.title( f" Number of Records ")

plt.subplot(1, 4, 2)
sns.barplot(x = products_group.sort_values(by = 'AvgPrice', ascending = False).index[ : 15], 
            y = products_group.sort_values(by = 'AvgPrice', ascending = False).AvgPrice.values[ : 15], 
            palette = "tab20b")
plt.xticks(rotation = 90)
plt.title( f" Avg Price")

plt.subplot(1, 4, 3)
sns.barplot(x = products_group.sort_values(by = 'AvgImages', ascending = False).index[ : 15], 
            y = products_group.sort_values(by = 'AvgImages', ascending = False).AvgImages.values[ : 15], 
            palette = "tab20b")
plt.xticks(rotation = 90)
plt.title( f" Avg Images")

plt.subplot(1, 4, 4)
sns.barplot(x = products_group.sort_values(by = 'AvgLength', ascending = False).index[ : 15], 
            y = products_group.sort_values(by = 'AvgLength', ascending = False).AvgLength.values[ : 15], 
            palette = "tab20b")
plt.xticks(rotation = 90)
plt.title( f" Avg Description Length ")


plt.show()

# %% [markdown]
# **Description length doesn't seem to play a key role in making decision.**
#
# **The products having highest average description doesn't have highest average price and highest number of records**

# %% [markdown]
# ### Analyzing  Attribute values in Desciption:

# %%
data.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price  NumImages  \
# 0  Unisex  11745          7
# 1   Women   5810          7
# 2   Women    899          7
# 3     Men   5599          5
# 4     Men    759          5
#
#                                          Description PrimaryColor NewGender  \
# 0  Black and grey printed medium trolley bag, sec...        Black    Unisex
# 1  Beige & Grey made to measure kurta with churid...        Beige     Women
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink     Women
# ...

# %% [markdown]
# **Finding the Percentage of number of records that have Primary Color value mentioned in the Description**

# %%
counter = 0
for i in range(  data.shape[0]  ) : 
    if (  data.loc[i , "PrimaryColor" ] in data.loc[i , "Description" ] )  : 
        counter += 1
        
print(round ( ( counter / data.shape[0] ) * 100 , 2))
# Out:
# 58.82

# %% [markdown]
# **Finding the Percentage of number of records that have Brand Name value mentioned in the Description**

# %%
counter = 0
for i in range(  data.shape[0]  ) : 
    if (  data.loc[i , "ProductBrand" ] in data.loc[i , "Description" ] )  : 
        counter += 1
        
print(round ( ( counter / data.shape[0] ) * 100 , 2))
# Out:
# 4.76

# %% [markdown]
# **Find the price distribution of the newgender for the products having primary color in description**

# %%
plt.figure(  figsize = (20, 15) )
plt.suptitle("Price distribution of Newgender for the products having primary color in description", fontsize = 20)

rowIndex = []
for i in range(  data.shape[0]  ) : 
    if (  data.loc[i , "PrimaryColor" ] in data.loc[i , "Description" ] )  : 
        rowIndex.append(i)

plt.subplot(3, 1, 1)
dfNew = data.loc[ rowIndex,  ]
sns.histplot( x = dfNew['Price'] ,hue = dfNew['NewGender'], palette = "viridis", bins = 25, multiple="stack")
plt.title(" ** Price Distribution : Range (90, 65000) ** ")

plt.subplot(3, 1, 2)
dfNew = dfNew[ dfNew["Price"] <= 10000 ]
sns.histplot( x = dfNew['Price'] ,hue = dfNew['NewGender'], palette = "viridis", bins = 25, multiple="stack")
plt.title(" ** Price Distribution : Range (90, 10000) ** ")

plt.subplot(3, 1, 3)
dfNew = dfNew[ dfNew["Price"] > 10000 ]
sns.histplot( x = dfNew['Price'] ,hue = dfNew['NewGender'], palette = "viridis", bins = 25, multiple="stack")
plt.title(" ** Price Distribution : Range (10000, 65000) ** ")

plt.show()

# %% [markdown]
# #### Records exceeding Rs. 10,000/- are nowhere to be found.

# %% [markdown]
# > NOTE : I am still working on this project and I will share the next version soon so stay updated by following :)

# %% [markdown]
# - Thank you so much for taking the time to explore this notebook with me. Your support means the world to me, and I couldn't have come this far without it. As I continue my journey in data science and machine learning, I humbly ask for your continued support and encouragement. Together, we can make a difference in the world of data science and beyond. 🚀💫

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Thanks for Being till here! 😊</h1>
